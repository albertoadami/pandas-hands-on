# %%
import pandas as pd

# %%
ice_cream = ["Chocolate", "Valilla", "Strawberry", "Run raisim"]
pd.Series(ice_cream)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31210ae45555> in <module>()
#       1 ice_cream = ["Chocolate", "Valilla", "Strawberry", "Run raisim"]
# ----> 2 pd.Series(ice_cream)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
ice_cream = ["Chocolate", "Valilla", "Strawberry", "Run raisim"]
pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Valilla
# 2    Strawberry
# 3    Run raisim
# dtype: object

# %%
lottery = [4, 5, 3, 4, 5]
pd.Series(lottery)
# Out:
# 0    4
# 1    5
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
webster = {"aaaaa": "An animal", "sdòkldjksòlks" : "A person"}
pd.Series(webster)
# Out:
# aaaaa            An animal
# sdòkldjksòlks     A person
# dtype: object

# %%
about_me = ["smart", "happy"]
s = pd.Series(about_me)

# %%
s
# Out:
# 0    smart
# 1    happy
# dtype: object

# %%
s.values
# Out:
# array(['smart', 'happy'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
s.dtype
# Out:
# dtype('O')

# %%
s.map(a -> a + "a")
# Out:
#   File "<ipython-input-12-3beedf11048c>", line 1
#     s.map(a -> a + "a")
#              ^
# SyntaxError: invalid syntax

# %%
prices = [233.4, 3737.34, 333.56]
s = pd.Series(prices)

# %%
s.sum
# Out:
# <bound method Series.sum of 0     233.40
# 1    3737.34
# 2     333.56
# dtype: float64>

# %% [markdown]
# s.sum()

# %%
s.sum()
# Out:
# 4304.3

# %%
s.mean()
# Out:
# 1434.7666666666667

# %%
pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze=True)
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
google = pd.read_csv("google_stock_price.csv", squeeze=True)

# %%
google.sum
# Out:
# <bound method Series.sum of 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
# 5        53.90
# 6        53.02
# 7        50.95
# 8        51.13
# 9        50.07
# 10       50.70
# 11       49.95
# 12       50.74
# 13       51.10
# 14       51.10
# 15       52.61
# 16       53.70
# 17       55.69
# 18       55.94
# 19       56.93
# 20       58.69
# 21       59.62
# 22       58.86
# 23       59.13
# 24       60.35
# 25       59.86
# 26       59.07
# 27       63.37
# 28       65.47
# 29       64.74
#          ...
# 2982    675.22
# 2983    668.26
# 2984    680.04
# 2985    684.11
# 2986    692.10
# 2987    699.21
# 2988    694.49
# 2989    697.77
# 2990    695.36
# 2991    705.63
# 2992    715.09
# 2993    720.64
# 2994    716.98
# 2995    720.95
# 2996    719.85
# 2997    733.78
# 2998    736.96
# 2999    741.19
# 3000    738.63
# 3001    742.74
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# ...

# %%
pokemon.head
# Out:
# -----------------------------------------------------------
# NameError                 Traceback (most recent call last)
# <ipython-input-25-8647ab5f5301> in <module>()
# ----> 1 pokemon.head
#
# NameError: name 'pokemon' is not defined

# %%
pokemon.head()
# Out:
# -----------------------------------------------------------
# NameError                 Traceback (most recent call last)
# <ipython-input-26-f113f09cf690> in <module>()
# ----> 1 pokemon.head()
#
# NameError: name 'pokemon' is not defined

# %%
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze=True)

# %%
pokemon.head(45)
# Out:
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
# 5      Charizard
# 6       Squirtle
# 7      Wartortle
# 8      Blastoise
# 9       Caterpie
# 10       Metapod
# 11    Butterfree
# 12        Weedle
# 13        Kakuna
# 14      Beedrill
# 15        Pidgey
# 16     Pidgeotto
# 17       Pidgeot
# 18       Rattata
# 19      Raticate
# 20       Spearow
# 21        Fearow
# 22         Ekans
# 23         Arbok
# 24       Pikachu
# 25        Raichu
# 26     Sandshrew
# 27     Sandslash
# 28       Nidoran
# 29      Nidorina
# 30     Nidoqueen
# 31      Nidoran♂
# 32      Nidorino
# 33      Nidoking
# 34      Clefairy
# 35      Clefable
# 36        Vulpix
# 37     Ninetales
# 38    Jigglypuff
# 39    Wigglytuff
# 40         Zubat
# 41        Golbat
# 42        Oddish
# 43         Gloom
# 44     Vileplume
# Name: Pokemon, dtype: object

# %%
pokemon.tail
# Out:
# <bound method Series.tail of 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# ...

# %%
google.tail()
# Out:
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, dtype: float64

# %%
google.tail(10)
# Out:
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, dtype: float64

# %%
len(google)
# Out:
# 3012

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
dir(pokemon)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Bronzong',
#  'Bronzor',
#  'Budew',
#  'Buizel',
#  'Bulbasaur',
#  'Buneary',
#  'Bunnelby',
# ...

# %%
max(pokemon)
# Out:
# 'Zygarde'

# %%
sum(pokemon)
# Out:
# -----------------------------------------------------------
# TypeError                 Traceback (most recent call last)
# <ipython-input-39-487c70fa4ec5> in <module>()
# ----> 1 sum(pokemon)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
sum(google)
# Out:
# 1006942.0000000002

# %%
pokemon.index
# Out:
# RangeIndex(start=0, stop=721, step=1)

# %%
pokemon.is_unique
# Out:
# True

# %%
pokemon.sort_values()
# Out:
# 459     Abomasnow
# 62           Abra
# 358         Absol
# 616      Accelgor
# 680     Aegislash
# 141    Aerodactyl
# 305        Aggron
# 189         Aipom
# 64       Alakazam
# 593     Alomomola
# 333       Altaria
# 697        Amaura
# 423       Ambipom
# 590     Amoonguss
# 180      Ampharos
# 346       Anorith
# 23          Arbok
# 58       Arcanine
# 492        Arceus
# 565        Archen
# 566      Archeops
# 167       Ariados
# 347       Armaldo
# 682    Aromatisse
# 303          Aron
# 143      Articuno
# 530        Audino
# 698       Aurorus
# 712       Avalugg
# 609          Axew
#           ...
# 69     Weepinbell
# 109       Weezing
# 546    Whimsicott
# 543    Whirlipede
# 339      Whiscash
# 292       Whismur
# 39     Wigglytuff
# 277       Wingull
# 201     Wobbuffet
# 526        Woobat
# 193        Wooper
# 412      Wormadam
# 264       Wurmple
# 359        Wynaut
# 177          Xatu
# 715       Xerneas
# 561        Yamask
# 192         Yanma
# 468       Yanmega
# ...

# %%
pokemon.sort_values().head()
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
# Name: Pokemon, dtype: object

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
pokemon.sort_index
# Out:
# <bound method Series.sort_index of 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# ...

# %%
pokemon[334]
# Out:
# 'Zangoose'

# %%
pokemon[[1, 29, 45]]
# Out:
# 1      Ivysaur
# 29    Nidorina
# 45       Paras
# Name: Pokemon, dtype: object

# %%
3 in [2, 44, 23]
# Out:
# False

# %%
pd.read_csv("pokemon.csv", index_col="Pokemon")
# Out:
#                 Type
# Pokemon
# Bulbasaur      Grass
# Ivysaur        Grass
# Venusaur       Grass
# Charmander      Fire
# Charmeleon      Fire
# Charizard       Fire
# Squirtle       Water
# Wartortle      Water
# Blastoise      Water
# Caterpie         Bug
# Metapod          Bug
# Butterfree       Bug
# Weedle           Bug
# Kakuna           Bug
# Beedrill         Bug
# Pidgey        Normal
# Pidgeotto     Normal
# Pidgeot       Normal
# Rattata       Normal
# Raticate      Normal
# Spearow       Normal
# Fearow        Normal
# Ekans         Poison
# Arbok         Poison
# Pikachu     Electric
# Raichu      Electric
# Sandshrew     Ground
# Sandslash     Ground
# Nidoran       Poison
# Nidorina      Poison
# ...              ...
# Clauncher      Water
# Clawitzer      Water
# Helioptile  Electric
# Heliolisk   Electric
# Tyrunt          Rock
# Tyrantrum       Rock
# Amaura          Rock
# Aurorus         Rock
# Sylveon        Fairy
# Hawlucha    Fighting
# Dedenne     Electric
# ...

# %%
pd.read_csv("pokemon.csv")
# Out:
#         Pokemon      Type
# 0     Bulbasaur     Grass
# 1       Ivysaur     Grass
# 2      Venusaur     Grass
# 3    Charmander      Fire
# 4    Charmeleon      Fire
# 5     Charizard      Fire
# 6      Squirtle     Water
# 7     Wartortle     Water
# 8     Blastoise     Water
# 9      Caterpie       Bug
# 10      Metapod       Bug
# 11   Butterfree       Bug
# 12       Weedle       Bug
# 13       Kakuna       Bug
# 14     Beedrill       Bug
# 15       Pidgey    Normal
# 16    Pidgeotto    Normal
# 17      Pidgeot    Normal
# 18      Rattata    Normal
# 19     Raticate    Normal
# 20      Spearow    Normal
# 21       Fearow    Normal
# 22        Ekans    Poison
# 23        Arbok    Poison
# 24      Pikachu  Electric
# 25       Raichu  Electric
# 26    Sandshrew    Ground
# 27    Sandslash    Ground
# 28      Nidoran    Poison
# 29     Nidorina    Poison
# ..          ...       ...
# 691   Clauncher     Water
# 692   Clawitzer     Water
# 693  Helioptile  Electric
# ...

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
pokemon = pd.read_csv("pokemon.csv", index_col="Pokemon", squeeze=True)
pokemon.sort_index(inplace=True)
pokemon.head(5)
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Psychic
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
# Name: Type, dtype: object

# %%
pokemon.head(3)
# Out:
# Pokemon
# Bulbasaur    Grass
# Ivysaur      Grass
# Venusaur     Grass
# Name: Type, dtype: object

# %%
pokemon.get("Bulbasaur")
# Out:
# 'Grass'

# %%
pokemon.value_counts()
# Out:
# Water       105
# Normal       93
# Grass        66
# Bug          63
# Fire         47
# Psychic      47
# Rock         41
# Electric     36
# Ground       30
# Dark         28
# Poison       28
# Fighting     25
# Dragon       24
# Ghost        23
# Ice          23
# Steel        22
# Fairy        17
# Flying        3
# Name: Type, dtype: int64

# %% [markdown]
# def classify_performance(number):
#     if(number < 2)
#         "OK"
#      else "BAD"

# %%
def classify_performance(number):
    if(number > 300):
        return "ok"
    else:
        return "bad"

# %%
google.apply(classify_performance)
# Out:
# 0       bad
# 1       bad
# 2       bad
# 3       bad
# 4       bad
# 5       bad
# 6       bad
# 7       bad
# 8       bad
# 9       bad
# 10      bad
# 11      bad
# 12      bad
# 13      bad
# 14      bad
# 15      bad
# 16      bad
# 17      bad
# 18      bad
# 19      bad
# 20      bad
# 21      bad
# 22      bad
# 23      bad
# 24      bad
# 25      bad
# 26      bad
# 27      bad
# 28      bad
# 29      bad
#        ...
# 2982     ok
# 2983     ok
# 2984     ok
# 2985     ok
# 2986     ok
# 2987     ok
# 2988     ok
# 2989     ok
# 2990     ok
# 2991     ok
# 2992     ok
# 2993     ok
# 2994     ok
# 2995     ok
# 2996     ok
# 2997     ok
# 2998     ok
# 2999     ok
# 3000     ok
# 3001     ok
# 3002     ok
# 3003     ok
# 3004     ok
# 3005     ok
# 3006     ok
# 3007     ok
# 3008     ok
# 3009     ok
# 3010     ok
# 3011     ok
# Name: Stock Price, Length: 3012, dtype: object

# %%
google.apply(lambda stock_price : stock_price + 1)
# Out:
# 0        51.12
# 1        55.10
# 2        55.65
# 3        53.38
# 4        53.95
# 5        54.90
# 6        54.02
# 7        51.95
# 8        52.13
# 9        51.07
# 10       51.70
# 11       50.95
# 12       51.74
# 13       52.10
# 14       52.10
# 15       53.61
# 16       54.70
# 17       56.69
# 18       56.94
# 19       57.93
# 20       59.69
# 21       60.62
# 22       59.86
# 23       60.13
# 24       61.35
# 25       60.86
# 26       60.07
# 27       64.37
# 28       66.47
# 29       65.74
#          ...
# 2982    676.22
# 2983    669.26
# 2984    681.04
# 2985    685.11
# 2986    693.10
# 2987    700.21
# 2988    695.49
# 2989    698.77
# 2990    696.36
# 2991    706.63
# 2992    716.09
# 2993    721.64
# 2994    717.98
# 2995    721.95
# 2996    720.85
# 2997    734.78
# 2998    737.96
# 2999    742.19
# 3000    739.63
# 3001    743.74
# 3002    740.77
# 3003    739.42
# 3004    742.77
# 3005    746.91
# 3006    769.79
# 3007    773.88
# 3008    772.07
# ...

# %%
pokemon_names = pd.read_csv("pokemon.csv", usecols=["Pokemon"], squeeze=True)

# %%
pokemon_types = pd.read_csv("pokemon.csv", index_col="Pokemon", squeeze=True)

# %%
pokemon_types
# Out:
# Pokemon
# Bulbasaur        Grass
# Ivysaur          Grass
# Venusaur         Grass
# Charmander        Fire
# Charmeleon        Fire
# Charizard         Fire
# Squirtle         Water
# Wartortle        Water
# Blastoise        Water
# Caterpie           Bug
# Metapod            Bug
# Butterfree         Bug
# Weedle             Bug
# Kakuna             Bug
# Beedrill           Bug
# Pidgey          Normal
# Pidgeotto       Normal
# Pidgeot         Normal
# Rattata         Normal
# Raticate        Normal
# Spearow         Normal
# Fearow          Normal
# Ekans           Poison
# Arbok           Poison
# Pikachu       Electric
# Raichu        Electric
# Sandshrew       Ground
# Sandslash       Ground
# Nidoran         Poison
# Nidorina        Poison
#                 ...
# Clauncher        Water
# Clawitzer        Water
# Helioptile    Electric
# Heliolisk     Electric
# Tyrunt            Rock
# Tyrantrum         Rock
# Amaura            Rock
# Aurorus           Rock
# ...

# %%
pokemon_names.map(pokemon_types)
# Out:
# 0         Grass
# 1         Grass
# 2         Grass
# 3          Fire
# 4          Fire
# 5          Fire
# 6         Water
# 7         Water
# 8         Water
# 9           Bug
# 10          Bug
# 11          Bug
# 12          Bug
# 13          Bug
# 14          Bug
# 15       Normal
# 16       Normal
# 17       Normal
# 18       Normal
# 19       Normal
# 20       Normal
# 21       Normal
# 22       Poison
# 23       Poison
# 24     Electric
# 25     Electric
# 26       Ground
# 27       Ground
# 28       Poison
# 29       Poison
#          ...
# 691       Water
# 692       Water
# 693    Electric
# 694    Electric
# 695        Rock
# 696        Rock
# 697        Rock
# 698        Rock
# 699       Fairy
# 700    Fighting
# 701    Electric
# 702        Rock
# 703      Dragon
# 704      Dragon
# 705      Dragon
# 706       Steel
# 707       Ghost
# 708       Ghost
# 709       Ghost
# 710       Ghost
# 711         Ice
# 712         Ice
# 713      Flying
# 714      Flying
# ...

# %%
pokemon_types.to_dict
# Out:
# <bound method Series.to_dict of Pokemon
# Bulbasaur        Grass
# Ivysaur          Grass
# Venusaur         Grass
# Charmander        Fire
# Charmeleon        Fire
# Charizard         Fire
# Squirtle         Water
# Wartortle        Water
# Blastoise        Water
# Caterpie           Bug
# Metapod            Bug
# Butterfree         Bug
# Weedle             Bug
# Kakuna             Bug
# Beedrill           Bug
# Pidgey          Normal
# Pidgeotto       Normal
# Pidgeot         Normal
# Rattata         Normal
# Raticate        Normal
# Spearow         Normal
# Fearow          Normal
# Ekans           Poison
# Arbok           Poison
# Pikachu       Electric
# Raichu        Electric
# Sandshrew       Ground
# Sandslash       Ground
# Nidoran         Poison
# Nidorina        Poison
#                 ...
# Clauncher        Water
# Clawitzer        Water
# Helioptile    Electric
# Heliolisk     Electric
# Tyrunt            Rock
# Tyrantrum         Rock
# Amaura            Rock
# ...

# %%
dict = pokemon_types.to_dict()

# %%
type(dict)
# Out:
# dict

# %%
dict
# Out:
# {'Abomasnow': 'Grass',
#  'Abra': 'Psychic',
#  'Absol': 'Dark',
#  'Accelgor': 'Bug',
#  'Aegislash': 'Steel',
#  'Aerodactyl': 'Rock',
#  'Aggron': 'Steel',
#  'Aipom': 'Normal',
#  'Alakazam': 'Psychic',
#  'Alomomola': 'Water',
#  'Altaria': 'Dragon',
#  'Amaura': 'Rock',
#  'Ambipom': 'Normal',
#  'Amoonguss': 'Grass',
#  'Ampharos': 'Electric',
#  'Anorith': 'Rock',
#  'Arbok': 'Poison',
#  'Arcanine': 'Fire',
#  'Arceus': 'Normal',
#  'Archen': 'Rock',
#  'Archeops': 'Rock',
#  'Ariados': 'Bug',
#  'Armaldo': 'Rock',
#  'Aromatisse': 'Fairy',
#  'Aron': 'Steel',
#  'Articuno': 'Ice',
#  'Audino': 'Normal',
#  'Aurorus': 'Rock',
#  'Avalugg': 'Ice',
#  'Axew': 'Dragon',
#  'Azelf': 'Psychic',
#  'Azumarill': 'Water',
#  'Azurill': 'Normal',
#  'Bagon': 'Dragon',
#  'Baltoy': 'Ground',
#  'Banette': 'Ghost',
#  'Barbaracle': 'Rock',
#  'Barboach': 'Water',
#  'Basculin': 'Water',
#  'Bastiodon': 'Rock',
#  'Bayleef': 'Grass',
#  'Beartic': 'Ice',
#  'Beautifly': 'Bug',
# ...
